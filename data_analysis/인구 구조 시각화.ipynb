# %%
import csv
f = open('age.csv')
data = csv.reader(f)

for row in data:
    if '신도림' in row[0]:
        print(row)
# Out:
# ['서울특별시 구로구 신도림동(1153051000)', '35,888', '35,888', '3,477', '3,528', '4,204', '6,049', '6,549', '5,090', '4,150', '1,995', '738', '104', '4']

# %%
print('신도림' in '서울특별시 구로구 신도림동(115051000)')
print('1153' in '서울특별시 구로구 신도림동(1153051000)')
print('()' in '서울특별시 구로구 신도림동(1153051000)')
# Out:
# True
# True
# False

# %%
import csv
f = open('age.csv', encoding='UTF-8')
data = csv.reader(f)

for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            print(i)
# Out:
# 311
# 331
# 344
# 388
# 397
# 407
# 396
# 432
# 414
# 394
# 409
# 398
# 372
# 350
# 362
# 328
# 333
# 357
# 370
# 405
# 372
# 404
# 445
# 506
# 458
# 499
# 443
# 461
# 500
# 445
# 553
# 536
# 563
# 606
# 592
# 666
# 759
# 755
# 811
# 696
# 749
# 666
# 685
# 625
# 680
# 690
# 674
# 626
# 642
# 629
# 572
# 527
# 490
# 523
# 554
# 484
# 497
# 503
# 558
# 536
# 523
# 469
# 446
# 403
# 485
# 371
# 370
# 362
# 243
# 291
# 264
# 263
# 272
# 160
# 161
# 146
# 166
# 177
# 140
# 110
# 112
# 105
# 86
# 97
# 57
# 53
# 40
# 43
# 30
# 24
# 25
# 18
# 11
# 12
# 11
# 4
# 9
# 1
# 3
# 4
# 8

# %%
import csv
f = open('age.csv', 'r', encoding='UTF-8')
data = csv.reader(f)
result=[] # 빈 리스트 만들기

for row in data:
    if '신도림' in row[0]: # '신도림'이 포함된 행정구역 찾기
        for i in row[3:]: # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            result.append(i) # 해당 연령의 인구수 리스트에 순서대로 저장하기
print(result) # 0세부터 100세 이상까지의 인구수 출력하기
# Out:
# ['311', '331', '344', '388', '397', '407', '396', '432', '414', '394', '409', '398', '372', '350', '362', '328', '333', '357', '370', '405', '372', '404', '445', '506', '458', '499', '443', '461', '500', '445', '553', '536', '563', '606', '592', '666', '759', '755', '811', '696', '749', '666', '685', '625', '680', '690', '674', '626', '642', '629', '572', '527', '490', '523', '554', '484', '497', '503', '558', '536', '523', '469', '446', '403', '485', '371', '370', '362', '243', '291', '264', '263', '272', '160', '161', '146', '166', '177', '140', '110', '112', '105', '86', '97', '57', '53', '40', '43', '30', '24', '25', '18', '11', '12', '11', '4', '9', '1', '3', '4', '8']

# %%
# 시각화하기
import csv
import matplotlib.pyplot as plt

f = open('age.csv', encoding='UTF-8')
data = csv.reader(f)
result=[] # 빈 리스트 만들기

for row in data:
    if '신도림' in row[0]: # '신도림'이 포함된 행정구역 찾기
        for i in row[3:]: # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            result.append(int(i)) # 해당 연령의 인구수 리스트에 순서대로 저장하기

plt.style.use('ggplot') # 격자 무늬 스타일 지정
plt.plot(result)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('age.csv', encoding='UTF-8')
data = csv.reader(f)
result = []
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요: ')
for row in data:
    if name in row[0]:
        for i in row[3:]:
            result.append(int(i))

plt.style.use('ggplot')
plt.rc('font', family='Malgun Gothic')
plt.title(name + '지역의 인구 구조')
plt.plot(result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요: 아름동

# %% [markdown]
# # 막대그래프 그리기

# %%
import matplotlib.pyplot as plt
plt.bar([0,1,2,4,6,10], [1,2,3,5,6,7])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(range(6), [1,2,3,5,6,7])
plt.show()

# %%
# 막대그래프를 활용해 우리 동네 인구 구조 시각화하기
import csv
f = open('age.csv', encoding='utf-8') 
data = csv.reader(f)
result = []

for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i))
            
import matplotlib.pyplot as plt
plt.bar(range(101), result)
plt.show()

# %%
# 수평 막대그래프 사용

import csv
f = open('age.csv', encoding='utf-8') 
data = csv.reader(f)
result = []

for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i))
            
import matplotlib.pyplot as plt
plt.barh(range(101), result)
plt.show()

# %% [markdown]
# # 남녀 구분

# %%
# 성별 데이터 저장하기 (Type 1)

import csv
f = open('gender.csv', encoding='utf-8')
data = csv.reader(f)
m = []
f = []
for row in data:
    if '신도림' in row[0]:
        for i in range(0, 101):
            m.append(int(row[i+3]))
            f.append(int(row[-(i+1)]))
f.reverse()

# %%
# 성별 데이터 저장하기 (Type 2)

import csv
f = open('gender.csv', encoding='utf-8')
data = csv.reader(f)
m = []
f = []
for row in data:
    if '신도림' in row[0]:
        for i in row[3:104]:
            m.append(int(i))
        for i in row[106:]:
            f.append(int(i))

# %%
import matplotlib.pyplot as plt
plt.barh(range(101), m)
plt.barh(range(101), f)
plt.show()

# %%
# 성별 데이터 수평 막대그래프로 시각화하기

import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='utf-8')
data = csv.reader(f)
m = []
f = []
for row in data:
    if '신도림' in row[0]:
        for i in range(0, 101):
            m.append(-int(row[i+3]))
            f.append(int(row[-(i+1)]))
f.reverse()

plt.rc('font', family = 'Malgun Gothic')
plt.title('신도림 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()
# Out:
# C:\Users\02280\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\02280\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 마이너스 부호 깨짐 해결

import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='utf-8')
data = csv.reader(f)
m = []
f = []
for row in data:
    if '신도림' in row[0]:
        for i in range(0, 101):
            m.append(-int(row[i+3]))
            f.append(int(row[-(i+1)]))
f.reverse()

plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title('신도림 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()

# %%
# 찾고 싶은 지역 이름 입력해서 항아리 모양 그래프 그리기

import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='utf-8')
data = csv.reader(f)
m = []
f = []

name = input('찾고 싶은 지역의 이름을 알려주세요: ')
for row in data:
    if name in row[0]:
        for i in row[3:104]:
            m.append(-int(i.replace(',','')))
        for i in row[106:]:
            f.append(int(i.replace(',','')))
        break
        
plt.style.use('ggplot')
plt.figure(figsize=(10, 5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요: 제주특별자치도

# %% [markdown]
# # 혈액형 비율 표현하기

# %%
import matplotlib.pyplot as plt
plt.pie([10, 20])
plt.show()

# %%
import matplotlib.pyplot as plt
size = [2441, 2312, 1031, 1233]
plt.axis('equal')
plt.pie(size)
plt.show()

# %%
# 레이블 추가하기

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic') # 그래프에 한글 표시
size = [2441, 2312, 1031, 1233] # 데이터
label = ['A형', 'B형', 'AB형', 'O형']
plt.axis('equal')
plt.pie(size, labels=label)
plt.show()

# %%
# 비율 및 범례 표시하기

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
size = [2441, 2312, 1031, 1233]
label = ['A형', 'B형', 'AB형', 'O형']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%')
plt.legend()
plt.show()

# %%
# 색 및 돌출 효과 정하기

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
size = [2441, 2312, 1031, 1233]
label = ['A형', 'B형', 'AB형', 'O형']
color = ['darkmagenta', 'deeppink', 'hotpink', 'pink']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%', colors=color, explode=(0,0,0.1,0))
plt.legend()
plt.show()

# %%
# 성별 연령별 인구 데이터 출력하기 및 실행결과

import csv

f = open('gender.csv', encoding='utf-8')
data = csv.reader(f)
size = []
name = input('알고 싶은 지역의 이름을 알려주세요: ')

for row in data:
    if name in row[0]:
        m = 0
        f = 0
        for i in range(101):
            m += int(row[i+3].replace(',','')) # 3~103번까지 데이터 더하기
            f += int(row[i+106].replace(',','')) # 106~206번까지 데이터 더하기
        break
size.append(m) # 남성 합계 데이터 리스트에 추가
size.append(f) # 여성 합계 데이터 리스트에 추가
print(size)
# Out:
# 알고 싶은 지역의 이름을 알려주세요: 제주특별자치도
# [339195, 337374]

# %%
# 파이 차트로 표현하기

import csv
f = open('gender.csv', encoding='utf-8')
data = csv.reader(f)

size = []

name = input('찾고 싶은 지역의 이름을 알려주세요: ')
for row in data:
    if name in row[0]:
        m = 0
        f = 0
        for i in range(101):
            m += int(row[i+3].replace(',','')) # 3~103번까지 데이터 더하기
            f += int(row[i+106].replace(',','')) # 106~206번까지 데이터 더하기
        break
size.append(m)
size.append(f)

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
color = ['crimson', 'darkcyan']
plt.axis('equal')
plt.pie(size, labels=['남', '여'], autopct = '%.1f%%', colors=color, startangle=90)
plt.show()

# %% [markdown]
# # 우리 동네 인구 구조를 산점도로 나타내기

# %%
# 성별 연령별 인구 데이터 저장하기

import csv
f = open('gender.csv', encoding='utf-8')
data = csv.reader(f)
m = []
f = []
name = input('궁금한 동네를 입력해 주세요: ')
for row in data:
    if name in row[0]:
        for i in range(3, 104): # 3부터 103까지
            m.append(int(row[i].replace(',','')))
            f.append(int(row[i+103].replace(',','')))
        break
        
import matplotlib.pyplot as plt
plt.plot(m, label = 'Male')
plt.plot(f, label = 'Female')
plt.legend()
plt.show()
# Out:
# 궁금한 동네를 입력해 주세요: 제주특별자치도

# %%
# 연령별 남성 인구 - 여성 인구 값 저장하기

import csv
f = open('gender.csv', encoding='utf-8')
data = csv.reader(f)
result = []
name = input('궁금한 동네를 입력해 주세요: ')
for row in data:
    if name in row[0]:
        for i in range(3, 104):
            result.append(int(row[i].replace(',','')) - int(row[i+103].replace(',','')))
        break
        
import matplotlib.pyplot as plt
plt.bar(range(101), result)
plt.show()
# Out:
# 궁금한 동네를 입력해 주세요: 제주특별자치도

# %%
# 산점도로 표현하기

import matplotlib.pyplot as plt
plt.scatter([1,2,3,4], [10,30,20,40])
plt.show()

# %%
# 버블 차트로 표현하기

import matplotlib.pyplot as plt
plt.scatter([1,2,3,4], [10,30,20,40], s=[100, 200, 250, 300])
plt.show()

# %%
# 버블 차트로 표현하기 (컬러 추가)

import matplotlib.pyplot as plt
plt.scatter([1,2,3,4], [10,30,20,40], s=[30, 60, 90, 120], c=['red', 'blue', 'green', 'gold'])
plt.show()

# %%
# 컬러바 추가

import matplotlib.pyplot as plt
plt.scatter([1,2,3,4], [10,30,20,40], s=[30,60,90,120], c=range(4))
plt.colorbar()
plt.show()

# %%
# 컬러맵 추가

import matplotlib.pyplot as plt
plt.scatter([1,2,3,4], [10,30,20,40], s=[30,60,90,120], c=range(4), cmap='jet')
plt.colorbar()
plt.show()

# %%
# 위치, 크기가 서로 다른 100개의 점 만들기

import matplotlib.pyplot as plt
import random
x = []
y = []
size = []
for i in range(100):
    x.append(random.randint(50, 100))
    y.append(random.randint(50, 100))
    size.append(random.randint(10, 100))
plt.scatter(x, y, s=size)
plt.show()

# %%
# 위치, 크기가 서로 다른 100개의 점 만들기

plt.scatter(x, y, s=size, c=size, cmap='jet')
plt.colorbar()
plt.show()

# %%
# 투명도 설정

plt.scatter(x, y, s=size, c=size, cmap='jet', alpha=0.7)
plt.colorbar()
plt.show()

# %%
# 남녀 연령별 인구 데이터 scatter() 함수로 표현하기

import csv
f = open('gender.csv', encoding='utf-8')
data = csv.reader(f)
m = []
f = []
name = input('궁금한 동네를 입력해 주세요: ')
for row in data:
    if name in row[0]:
        for i in range(3, 104):
            m.append(int(row[i].replace(',','')))
            f.append(int(row[i+103].replace(',', '')))
        break
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.scatter(m, f)
plt.show()
# Out:
# 궁금한 동네를 입력해 주세요: 제주특별자치도

# %%
# y=x 형태의 추세선 추가하기

import matplotlib.pyplot as plt
plt.scatter(m, f, c=range(101), alpha=0.5, cmap='jet') # 컬러맵 적용
plt.colorbar()
plt.plot(range(max(m)), range(max(m)), 'g') # 추세선 추가
plt.show()

# %%
import csv
import math
f = open('gender.csv', encoding='utf-8')
data = csv.reader(f)
m = []
f = []
size = []
name = input('궁금한 동네를 입력해 주세요: ')
for row in data:
    if name in row[0]:
        for i in range(3, 104):
            m.append(int(row[i].replace(',','')))
            f.append(int(row[i+103].replace(',','')))
            size.append(math.sqrt(int(row[i].replace(',','')) + int(row[i+103].replace(',',''))))
        break
        
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(10,5), dpi=300)
plt.title(name + '지역의 성별 인구 그래프')
plt.scatter(m, f, s=size, c=range(101), alpha=0.5, cmap='jet')
plt.colorbar()
plt.plot(range(max(m)), range(max(m)), 'g')
plt.xlabel('남성 인구 수')
plt.ylabel('여성 인구 수')
plt.show()
# Out:
# 궁금한 동네를 입력해 주세요: 제주특별자치도

# %%
# 데이터 출력해 보기

import csv
f = open('subwayfee.csv', encoding='utf-8')
data = csv.reader(f)

for row in data:
    print(row)
# Out:
# ['\ufeff사용월', '호선명', '역ID', '지하철역', '유임승차', '유임하차', '무임승차', '무임하차']
# ['21-Oct', '1호선', '1', '서울역', '944239', '912544', '177275', '169112']
# ['21-Oct', '1호선', '10', '동묘앞', '122187', '132713', '155492', '155809']
# ['21-Oct', '1호선', '2', '시청', '438336', '445371', '66943', '67070']
# ['21-Oct', '1호선', '3', '종각', '685491', '661347', '111599', '104946']
# ['21-Oct', '1호선', '4', '종로3가', '415268', '373725', '274237', '255943']
# ['21-Oct', '1호선', '5', '종로5가', '339009', '344401', '242099', '233616']
# ['21-Oct', '1호선', '6', '동대문', '201326', '189813', '114922', '114248']
# ['21-Oct', '1호선', '7', '신설동', '247767', '243062', '107326', '104263']
# ['21-Oct', '1호선', '8', '제기동', '213183', '207058', '252606', '270194']
# ['21-Oct', '1호선', '9', '청량리(서울시립대입구)', '303834', '304025', '241762', '244447']
# ['21-Oct', '2호선', '11', '시청', '461536', '441619', '45265', '40536']
# ['21-Oct', '2호선', '12', '을지로입구', '803655', '821192', '82301', '76695']
# ['21-Oct', '2호선', '13', '을지로3가', '436964', '431666', '63379', '63081']
# ['21-Oct', '2호선', '14', '을지로4가', '230416', '230662', '74730', '74124']
# ['21-Oct', '2호선', '15', '동대문역사문화공원(DDP)', '263338', '300651', '49337', '52858']
# ['21-Oct', '2호선', '16', '신당', '274013', '287289', '88607', '90471']
# ['21-Oct', '2호선', '17', '상왕십리', '298601', '288243', '61888', '62165']
# ['21-Oct', '2호선', '18', '왕십리(성동구청)', '370380', '303556', '46699', '38807']
# ['21-Oct', '2호선', '19', '한양대', '171445', '183653', '11214', '11643']
# ['21-Oct', '2호선', '20', '뚝섬', '485879', '519998', '52993', '53585']
# ['21-Oct', '2호선', '21', '성수', '765947', '845897', '92747', '94347']
# ['21-Oct', '2호선', '22', '건대입구', '851977', '909153', '81351', '84944']
# ['21-Oct', '2호선', '23', '구의(광진구청)', '500573', '491138', '92219', '93882']
# ['21-Oct', '2호선', '24', '강변(동서울터미널)', '718744', '703401', '107914', '106784']
# ['21-Oct', '2호선', '25', '잠실나루', '280259', '274139', '71933', '72486']
# ['21-Oct', '2호선', '26', '잠실(송파구청)', '1657082', '1626991', '168704', '159180']
# ['21-Oct', '2호선', '27', '잠실새내', '444882', '447667', '91075', '91059']
# ['21-Oct', '2호선', '28', '종합운동장', '152481', '165826', '37810', '39259']
# ['21-Oct', '2호선', '29', '삼성(무역센터)', '1105245', '1127326', '95746', '88665']
# ['21-Oct', '2호선', '30', '선릉', '1080261', '960603', '186845', '165764']
# ['21-Oct', '2호선', '31', '역삼', '989233', '1109458', '131300', '132638']
# ['21-Oct', '2호선', '32', '강남', '1866020', '1841651', '148128', '132549']
# ['21-Oct', '2호선', '33', '교대(법원.검찰청)', '667441', '756080', '128541', '144723']
# ['21-Oct', '2호선', '34', '서초', '449810', '426796', '66647', '66239']
# ['21-Oct', '2호선', '35', '방배', '354784', '376404', '65062', '64302']
# ['21-Oct', '2호선', '36', '사당', '791209', '882066', '162753', '157398']
# ['21-Oct', '2호선', '37', '낙성대(강감찬)', '617893', '590670', '95336', '96849']
# ['21-Oct', '2호선', '38', '서울대입구(관악구청)', '1072698', '1057882', '167177', '159807']
# ['21-Oct', '2호선', '39', '봉천', '484652', '442585', '127822', '127622']
# ['21-Oct', '2호선', '40', '신림', '1437979', '1388244', '206887', '208518']
# ['21-Oct', '2호선', '41', '신대방', '573387', '555942', '115112', '116094']
# ['21-Oct', '2호선', '42', '구로디지털단지', '1289923', '1287755', '147777', '150043']
# ['21-Oct', '2호선', '43', '대림(구로구청)', '523600', '539214', '106291', '110020']
# ['21-Oct', '2호선', '44', '신도림', '1088339', '1084064', '174981', '166034']
# ['21-Oct', '2호선', '45', '문래', '439612', '453771', '70457', '69563']
# ['21-Oct', '2호선', '46', '영등포구청', '460921', '471330', '91270', '89502']
# ['21-Oct', '2호선', '47', '당산', '414707', '478707', '54418', '59764']
# ['21-Oct', '2호선', '48', '합정', '757443', '801357', '62285', '61890']
# ['21-Oct', '2호선', '49', '홍대입구', '1393038', '1454651', '87877', '83882']
# ['21-Oct', '2호선', '50', '신촌', '748944', '763910', '106563', '104048']
# ['21-Oct', '2호선', '51', '이대', '289394', '304965', '43015', '44513']
# ['21-Oct', '2호선', '52', '아현', '213518', '203790', '58209', '57309']
# ['21-Oct', '2호선', '53', '충정로(경기대입구)', '194443', '206233', '43008', '42722']
# ['21-Oct', '2호선', '54', '용답', '56735', '55701', '16315', '16310']
# ['21-Oct', '2호선', '55', '신답', '32031', '36740', '8545', '9133']
# ['21-Oct', '2호선', '56', '신설동', '59208', '48787', '30286', '27709']
# ['21-Oct', '2호선', '57', '도림천', '26346', '26981', '6670', '7045']
# ['21-Oct', '2호선', '58', '양천구청', '130389', '139120', '41952', '42268']
# ['21-Oct', '2호선', '59', '신정네거리', '198654', '206621', '66076', '66542']
# ['21-Oct', '2호선', '60', '용두(동대문구청)', '38897', '39158', '20415', '21707']
# ['21-Oct', '3호선', '61', '지축', '93228', '89685', '22022', '21292']
# ['21-Oct', '3호선', '62', '구파발', '437649', '423594', '105976', '101784']
# ['21-Oct', '3호선', '63', '연신내', '744925', '697845', '237029', '229959']
# ['21-Oct', '3호선', '64', '불광', '311268', '337290', '129630', '142171']
# ['21-Oct', '3호선', '65', '녹번', '321591', '287059', '68400', '67781']
# ['21-Oct', '3호선', '66', '홍제', '329579', '308877', '125779', '122566']
# ['21-Oct', '3호선', '67', '무악재', '74028', '74620', '26880', '29386']
# ['21-Oct', '3호선', '68', '독립문', '129308', '137378', '64953', '64457']
# ['21-Oct', '3호선', '69', '경복궁(정부서울청사)', '462794', '474769', '72498', '69902']
# ['21-Oct', '경부선', '267', '오산대', '82759', '77093', '17348', '16699']
# ['21-Oct', '경부선', '268', '오산', '238919', '235974', '42965', '43671']
# ['21-Oct', '경부선', '269', '진위', '34656', '29918', '7534', '7249']
# ['21-Oct', '경부선', '270', '송탄', '109554', '104675', '19983', '19166']
# ['21-Oct', '경부선', '271', '서정리', '168078', '158801', '29429', '28702']
# ['21-Oct', '경부선', '272', '평택지제', '82101', '78734', '10909', '10548']
# ['21-Oct', '경부선', '273', '평택', '303781', '299508', '61597', '60098']
# ['21-Oct', '경부선', '274', '성환', '90321', '90384', '18741', '18759']
# ['21-Oct', '경부선', '275', '직산', '16998', '17304', '4656', '4513']
# ['21-Oct', '경부선', '276', '두정', '141230', '143096', '25792', '26190']
# ['21-Oct', '경부선', '277', '천안', '123516', '125048', '53061', '53883']
# ['21-Oct', '경부선', '278', '당정', '130175', '124570', '28452', '27455']
# ['21-Oct', '경부선', '279', '서동탄', '30787', '28233', '7757', '7357']
# ['21-Oct', '경부선', '280', '광명', '83532', '71624', '9063', '8589']
# ['21-Oct', '경인선', '294', '개봉', '428445', '423852', '140520', '145837']
# ['21-Oct', '경인선', '295', '오류동', '237971', '218396', '81678', '79703']
# ['21-Oct', '경인선', '296', '역곡', '569079', '560341', '141061', '143252']
# ['21-Oct', '경인선', '297', '부천', '706966', '709480', '184820', '187414']
# ['21-Oct', '경인선', '298', '송내', '576949', '578899', '109166', '108245']
# ['21-Oct', '경인선', '299', '부평', '698638', '753946', '125450', '127491']
# ['21-Oct', '경인선', '300', '백운', '137548', '133781', '53071', '53443']
# ['21-Oct', '경인선', '301', '동암', '317083', '321059', '86875', '88184']
# ['21-Oct', '경인선', '302', '주안', '426280', '386108', '80160', '71409']
# ['21-Oct', '경인선', '303', '제물포', '219989', '211056', '57831', '57619']
# ['21-Oct', '경인선', '304', '동인천', '273871', '261207', '108313', '104923']
# ['21-Oct', '경인선', '305', '인천', '78104', '56995', '41138', '37625']
# ['21-Oct', '경인선', '306', '구일', '127665', '128229', '38990', '38240']
# ['21-Oct', '경인선', '307', '소사', '184140', '179533', '57684', '57561']
# ['21-Oct', '경인선', '308', '부개', '170870', '157406', '57126', '56009']
# ['21-Oct', '경인선', '309', '간석', '114628', '108878', '40518', '39707']
# ['21-Oct', '경인선', '310', '도원', '56349', '56491', '26924', '28278']
# ['21-Oct', '경인선', '311', '온수(성공회대입구)', '138610', '131484', '44258', '42996']
# ['21-Oct', '경인선', '312', '중동', '182743', '169566', '63451', '62503']
# ['21-Oct', '경인선', '313', '도화', '75456', '68524', '36308', '34780']
# ['21-Oct', '경원선', '128', '이촌(국립중앙박물관)', '75894', '56210', '24331', '20954']
# ['21-Oct', '경원선', '129', '서빙고', '39158', '39075', '13701', '12933']
# ['21-Oct', '경원선', '130', '한남', '80745', '76173', '26170', '24518']
# ['21-Oct', '경원선', '131', '옥수', '1483', '1001', '92', '78']
# ['21-Oct', '경원선', '132', '응봉', '34141', '28694', '15714', '13985']
# ['21-Oct', '경원선', '133', '왕십리(성동구청)', '317379', '361813', '56037', '61927']
# ['21-Oct', '경원선', '134', '청량리(서울시립대입구)', '310112', '318866', '138651', '147692']
# ['21-Oct', '경원선', '136', '외대앞', '152501', '149721', '39564', '40467']
# ['21-Oct', '경원선', '137', '신이문', '159086', '144496', '62510', '60960']
# ['21-Oct', '경원선', '138', '석계', '163352', '184414', '58635', '62913']
# ['21-Oct', '경원선', '139', '광운대', '164409', '158841', '49298', '48044']
# ['21-Oct', '경원선', '140', '월계', '124935', '115711', '56473', '54117']
# ['21-Oct', '경원선', '141', '녹천', '86877', '71295', '36116', '32291']
# ['21-Oct', '경원선', '142', '창동', '5', '0', '0', '0']
# ['21-Oct', '경원선', '359', '방학', '163916', '158632', '96730', '94766']
# ['21-Oct', '경원선', '360', '도봉', '98527', '92645', '65553', '65173']
# ['21-Oct', '경원선', '361', '도봉산', '138688', '79013', '119546', '95864']
# ['21-Oct', '경원선', '362', '망월사', '139419', '141873', '63456', '65208']
# ['21-Oct', '경원선', '363', '회룡', '204118', '202339', '134070', '132547']
# ['21-Oct', '경원선', '364', '의정부', '412889', '426001', '96653', '98589']
# ['21-Oct', '경원선', '365', '가능', '128391', '120737', '53138', '52950']
# ['21-Oct', '경원선', '366', '녹양', '88933', '84669', '34759', '33520']
# ['21-Oct', '경원선', '367', '양주', '165881', '156439', '56882', '56077']
# ['21-Oct', '경원선', '368', '덕계', '62281', '55800', '21075', '20194']
# ['21-Oct', '경원선', '369', '덕정', '123943', '119287', '32855', '32878']
# ['21-Oct', '경원선', '370', '지행', '135839', '135169', '42315', '42301']
# ['21-Oct', '경원선', '371', '동두천중앙', '55027', '52697', '33208', '33270']
# ['21-Oct', '경원선', '372', '보산', '36432', '33560', '12739', '11996']
# ['21-Oct', '경원선', '373', '동두천', '35638', '40656', '22574', '28658']
# ['21-Oct', '경원선', '374', '소요산', '36476', '29865', '77461', '69584']
# ['21-Oct', '안산선', '281', '산본', '333670', '362506', '86951', '88231']
# ['21-Oct', '안산선', '282', '대야미', '105919', '94119', '30689', '29129']
# ['21-Oct', '안산선', '283', '반월', '89963', '85822', '27262', '26910']
# ['21-Oct', '안산선', '284', '상록수', '365583', '367317', '63771', '64852']
# ['21-Oct', '안산선', '285', '한대앞', '211203', '210331', '41972', '42574']
# ['21-Oct', '안산선', '286', '중앙', '432098', '448113', '53208', '52635']
# ['21-Oct', '안산선', '287', '고잔', '197891', '190547', '32930', '31786']
# ['21-Oct', '안산선', '288', '초지', '109535', '115733', '14977', '15153']
# ['21-Oct', '안산선', '289', '안산', '288202', '268127', '35523', '33455']
# ['21-Oct', '안산선', '290', '신길온천', '37599', '34852', '9816', '9751']
# ['21-Oct', '안산선', '291', '정왕', '216474', '223508', '24216', '25914']
# ['21-Oct', '안산선', '292', '오이도', '205128', '202141', '38433', '37865']
# ['21-Oct', '안산선', '293', '수리산', '80920', '65606', '29918', '28837']
# ['21-Oct', '과천선', '231', '선바위', '177040', '153229', '32060', '31511']
# ['21-Oct', '9호선', '629', '신반포', '68309', '67061', '17294', '17277']
# ['21-Oct', '9호선', '630', '고속터미널', '296684', '396218', '50983', '58493']
# ['21-Oct', '9호선', '631', '사평', '68415', '67127', '17712', '17844']
# ['21-Oct', '9호선', '632', '신논현', '741962', '731199', '52288', '48218']
# ['21-Oct', '공항철도 1호선', '646', '서울역', '192334', '183727', '29813', '26555']
# ['21-Oct', '공항철도 1호선', '647', '공덕', '50742', '67612', '6568', '7530']
# ['21-Oct', '공항철도 1호선', '648', '홍대입구', '263062', '260984', '16232', '15246']
# ['21-Oct', '공항철도 1호선', '649', '디지털미디어시티', '286913', '263467', '22451', '21101']
# ['21-Oct', '공항철도 1호선', '650', '마곡나루(서울식물원)', '175706', '172005', '12217', '12255']
# ['21-Oct', '공항철도 1호선', '651', '김포공항', '342297', '189221', '23677', '15211']
# ['21-Oct', '공항철도 1호선', '652', '계양', '228598', '214978', '27283', '25658']
# ['21-Oct', '공항철도 1호선', '653', '검암', '157999', '156346', '16870', '16902']
# ['21-Oct', '공항철도 1호선', '654', '청라국제도시', '153893', '146468', '11472', '11181']
# ['21-Oct', '공항철도 1호선', '655', '운서', '156953', '159041', '25854', '26039']
# ['21-Oct', '공항철도 1호선', '656', '공항화물청사', '48340', '53281', '8141', '8055']
# ['21-Oct', '공항철도 1호선', '657', '인천공항1터미널', '89581', '90275', '15432', '15262']
# ['21-Oct', '공항철도 1호선', '658', '인천공항2터미널', '52161', '48596', '6988', '6594']
# ['21-Oct', '공항철도 1호선', '659', '영종', '66724', '67972', '19561', '19601']
# ['21-Oct', '9호선2~3단계', '633', '언주', '224218', '230019', '24244', '24057']
# ['21-Oct', '9호선2~3단계', '634', '선정릉', '205666', '227262', '20999', '21582']
# ['21-Oct', '9호선2~3단계', '635', '삼성중앙', '134125', '141155', '19018', '19139']
# ['21-Oct', '9호선2~3단계', '636', '봉은사', '352072', '362850', '37898', '36181']
# ['21-Oct', '9호선2~3단계', '637', '종합운동장', '87986', '86735', '15872', '14198']
# ['21-Oct', '9호선2~3단계', '638', '삼전', '141938', '137435', '32021', '31199']
# ['21-Oct', '9호선2~3단계', '639', '석촌고분', '122814', '121093', '28642', '28783']
# ['21-Oct', '9호선2~3단계', '640', '석촌', '188918', '165930', '30547', '26556']
# ['21-Oct', '9호선2~3단계', '641', '송파나루', '106458', '114264', '22102', '22763']
# ['21-Oct', '9호선2~3단계', '642', '한성백제', '57606', '51281', '15237', '13643']
# ['21-Oct', '9호선2~3단계', '643', '올림픽공원(한국체대)', '156453', '162389', '27569', '27082']
# ['21-Oct', '9호선2~3단계', '644', '둔촌오륜', '24812', '22056', '5627', '5844']
# ['21-Oct', '9호선2~3단계', '645', '중앙보훈병원', '180064', '159215', '71410', '70180']
# ['21-Oct', '우이신설선', '703', '북한산우이', '59901', '53517', '35340', '36780']
# ['21-Oct', '우이신설선', '704', '솔밭공원', '39361', '35406', '25507', '26829']
# ['21-Oct', '우이신설선', '705', '4.19민주묘지', '47136', '45146', '33743', '29650']
# ['21-Oct', '우이신설선', '706', '가오리', '67784', '64150', '42263', '43493']
# ['21-Oct', '우이신설선', '707', '화계', '52907', '47353', '37661', '37855']
# ['21-Oct', '우이신설선', '708', '삼양', '29231', '29862', '24543', '26967']
# ['21-Oct', '우이신설선', '709', '삼양사거리', '34034', '34338', '33187', '32764']
# ['21-Oct', '우이신설선', '710', '솔샘', '110876', '100316', '34753', '35739']
# ['21-Oct', '우이신설선', '711', '북한산보국문', '119076', '110212', '39546', '39753']
# ['21-Oct', '우이신설선', '712', '정릉', '80616', '70311', '42140', '38705']
# ['21-Oct', '우이신설선', '713', '성신여대입구(돈암)', '61616', '71377', '26180', '24888']
# ['21-Oct', '우이신설선', '714', '보문', '26176', '25876', '13692', '13777']
# ['21-Oct', '우이신설선', '715', '신설동', '31729', '32903', '23652', '21185']

# %%
# 인원 숫자 데이터 정수로 바꾸기

import csv
f = open('subwayfee.csv', encoding='utf-8')
data = csv.reader(f)
next(data)

for row in data:
    for i in range(4, 8):
        row[i] = int(row[i])
    print(row)
# Out:
# ['21-Oct', '1호선', '1', '서울역', 944239, 912544, 177275, 169112]
# ['21-Oct', '1호선', '10', '동묘앞', 122187, 132713, 155492, 155809]
# ['21-Oct', '1호선', '2', '시청', 438336, 445371, 66943, 67070]
# ['21-Oct', '1호선', '3', '종각', 685491, 661347, 111599, 104946]
# ['21-Oct', '1호선', '4', '종로3가', 415268, 373725, 274237, 255943]
# ['21-Oct', '1호선', '5', '종로5가', 339009, 344401, 242099, 233616]
# ['21-Oct', '1호선', '6', '동대문', 201326, 189813, 114922, 114248]
# ['21-Oct', '1호선', '7', '신설동', 247767, 243062, 107326, 104263]
# ['21-Oct', '1호선', '8', '제기동', 213183, 207058, 252606, 270194]
# ['21-Oct', '1호선', '9', '청량리(서울시립대입구)', 303834, 304025, 241762, 244447]
# ['21-Oct', '2호선', '11', '시청', 461536, 441619, 45265, 40536]
# ['21-Oct', '2호선', '12', '을지로입구', 803655, 821192, 82301, 76695]
# ['21-Oct', '2호선', '13', '을지로3가', 436964, 431666, 63379, 63081]
# ['21-Oct', '2호선', '14', '을지로4가', 230416, 230662, 74730, 74124]
# ['21-Oct', '2호선', '15', '동대문역사문화공원(DDP)', 263338, 300651, 49337, 52858]
# ['21-Oct', '2호선', '16', '신당', 274013, 287289, 88607, 90471]
# ['21-Oct', '2호선', '17', '상왕십리', 298601, 288243, 61888, 62165]
# ['21-Oct', '2호선', '18', '왕십리(성동구청)', 370380, 303556, 46699, 38807]
# ['21-Oct', '2호선', '19', '한양대', 171445, 183653, 11214, 11643]
# ['21-Oct', '2호선', '20', '뚝섬', 485879, 519998, 52993, 53585]
# ['21-Oct', '2호선', '21', '성수', 765947, 845897, 92747, 94347]
# ['21-Oct', '2호선', '22', '건대입구', 851977, 909153, 81351, 84944]
# ['21-Oct', '2호선', '23', '구의(광진구청)', 500573, 491138, 92219, 93882]
# ['21-Oct', '2호선', '24', '강변(동서울터미널)', 718744, 703401, 107914, 106784]
# ['21-Oct', '2호선', '25', '잠실나루', 280259, 274139, 71933, 72486]
# ['21-Oct', '2호선', '26', '잠실(송파구청)', 1657082, 1626991, 168704, 159180]
# ['21-Oct', '2호선', '27', '잠실새내', 444882, 447667, 91075, 91059]
# ['21-Oct', '2호선', '28', '종합운동장', 152481, 165826, 37810, 39259]
# ['21-Oct', '2호선', '29', '삼성(무역센터)', 1105245, 1127326, 95746, 88665]
# ['21-Oct', '2호선', '30', '선릉', 1080261, 960603, 186845, 165764]
# ['21-Oct', '2호선', '31', '역삼', 989233, 1109458, 131300, 132638]
# ['21-Oct', '2호선', '32', '강남', 1866020, 1841651, 148128, 132549]
# ['21-Oct', '2호선', '33', '교대(법원.검찰청)', 667441, 756080, 128541, 144723]
# ['21-Oct', '2호선', '34', '서초', 449810, 426796, 66647, 66239]
# ['21-Oct', '2호선', '35', '방배', 354784, 376404, 65062, 64302]
# ['21-Oct', '2호선', '36', '사당', 791209, 882066, 162753, 157398]
# ['21-Oct', '2호선', '37', '낙성대(강감찬)', 617893, 590670, 95336, 96849]
# ['21-Oct', '2호선', '38', '서울대입구(관악구청)', 1072698, 1057882, 167177, 159807]
# ['21-Oct', '2호선', '39', '봉천', 484652, 442585, 127822, 127622]
# ['21-Oct', '2호선', '40', '신림', 1437979, 1388244, 206887, 208518]
# ['21-Oct', '2호선', '41', '신대방', 573387, 555942, 115112, 116094]
# ['21-Oct', '2호선', '42', '구로디지털단지', 1289923, 1287755, 147777, 150043]
# ['21-Oct', '2호선', '43', '대림(구로구청)', 523600, 539214, 106291, 110020]
# ['21-Oct', '2호선', '44', '신도림', 1088339, 1084064, 174981, 166034]
# ['21-Oct', '2호선', '45', '문래', 439612, 453771, 70457, 69563]
# ['21-Oct', '2호선', '46', '영등포구청', 460921, 471330, 91270, 89502]
# ['21-Oct', '2호선', '47', '당산', 414707, 478707, 54418, 59764]
# ['21-Oct', '2호선', '48', '합정', 757443, 801357, 62285, 61890]
# ['21-Oct', '2호선', '49', '홍대입구', 1393038, 1454651, 87877, 83882]
# ['21-Oct', '2호선', '50', '신촌', 748944, 763910, 106563, 104048]
# ['21-Oct', '2호선', '51', '이대', 289394, 304965, 43015, 44513]
# ['21-Oct', '2호선', '52', '아현', 213518, 203790, 58209, 57309]
# ['21-Oct', '2호선', '53', '충정로(경기대입구)', 194443, 206233, 43008, 42722]
# ['21-Oct', '2호선', '54', '용답', 56735, 55701, 16315, 16310]
# ['21-Oct', '2호선', '55', '신답', 32031, 36740, 8545, 9133]
# ['21-Oct', '2호선', '56', '신설동', 59208, 48787, 30286, 27709]
# ['21-Oct', '2호선', '57', '도림천', 26346, 26981, 6670, 7045]
# ['21-Oct', '2호선', '58', '양천구청', 130389, 139120, 41952, 42268]
# ['21-Oct', '2호선', '59', '신정네거리', 198654, 206621, 66076, 66542]
# ['21-Oct', '2호선', '60', '용두(동대문구청)', 38897, 39158, 20415, 21707]
# ['21-Oct', '3호선', '61', '지축', 93228, 89685, 22022, 21292]
# ['21-Oct', '3호선', '62', '구파발', 437649, 423594, 105976, 101784]
# ['21-Oct', '3호선', '63', '연신내', 744925, 697845, 237029, 229959]
# ['21-Oct', '3호선', '64', '불광', 311268, 337290, 129630, 142171]
# ['21-Oct', '3호선', '65', '녹번', 321591, 287059, 68400, 67781]
# ['21-Oct', '3호선', '66', '홍제', 329579, 308877, 125779, 122566]
# ['21-Oct', '3호선', '67', '무악재', 74028, 74620, 26880, 29386]
# ['21-Oct', '3호선', '68', '독립문', 129308, 137378, 64953, 64457]
# ['21-Oct', '3호선', '69', '경복궁(정부서울청사)', 462794, 474769, 72498, 69902]
# ['21-Oct', '3호선', '70', '안국', 449963, 479175, 76847, 79980]
# ['21-Oct', '3호선', '71', '종로3가', 196264, 239092, 51802, 58432]
# ['21-Oct', '3호선', '72', '을지로3가', 196152, 205714, 44144, 42159]
# ['21-Oct', '3호선', '73', '충무로', 27, 0, 2, 0]
# ['21-Oct', '3호선', '74', '동대입구', 175766, 188426, 32647, 36009]
# ['21-Oct', '3호선', '75', '약수', 258775, 255628, 73457, 70189]
# ['21-Oct', '3호선', '76', '금호', 159078, 147040, 48266, 47601]
# ['21-Oct', '3호선', '77', '옥수', 185182, 194254, 53476, 53777]
# ['21-Oct', '3호선', '78', '압구정', 669125, 715818, 114132, 111858]
# ['21-Oct', '3호선', '79', '신사', 705517, 742033, 65201, 62782]
# ['21-Oct', '3호선', '80', '잠원', 96929, 95702, 27122, 26314]
# ['21-Oct', '3호선', '81', '고속터미널', 1024635, 1010805, 155711, 150910]
# ['21-Oct', '3호선', '82', '교대(법원.검찰청)', 278085, 178170, 56975, 34424]
# ['21-Oct', '3호선', '83', '남부터미널(예술의전당)', 627695, 647352, 106046, 107661]
# ['21-Oct', '3호선', '84', '양재(서초구청)', 791330, 873867, 129889, 131820]
# ['21-Oct', '3호선', '85', '매봉', 239649, 231784, 54752, 50509]
# ['21-Oct', '3호선', '86', '도곡', 108011, 111841, 22485, 21050]
# ['21-Oct', '3호선', '87', '대치', 230465, 225730, 53567, 51170]
# ['21-Oct', '3호선', '88', '학여울', 43801, 46203, 15726, 15469]
# ['21-Oct', '3호선', '89', '대청', 200662, 183415, 51189, 49311]
# ['21-Oct', '3호선', '90', '일원', 184519, 181446, 52657, 52223]
# ['21-Oct', '3호선', '91', '수서', 356946, 365078, 93017, 91808]
# ['21-Oct', '3호선', '92', '가락시장', 155602, 153086, 63909, 61911]
# ['21-Oct', '3호선', '93', '경찰병원', 140040, 139673, 35942, 36961]
# ['21-Oct', '3호선', '94', '오금', 129412, 117328, 25248, 23896]
# ['21-Oct', '4호선', '100', '수유(강북구청)', 714183, 706625, 172222, 170930]
# ['21-Oct', '4호선', '101', '미아(서울사이버대학)', 293680, 278712, 97083, 99361]
# ['21-Oct', '4호선', '102', '미아사거리', 568729, 545477, 162804, 160763]
# ['21-Oct', '4호선', '103', '길음', 414210, 401008, 98484, 98612]
# ['21-Oct', '4호선', '104', '성신여대입구(돈암)', 459498, 437803, 75421, 73732]
# ['21-Oct', '4호선', '105', '한성대입구(삼선교)', 292576, 283609, 67201, 66135]
# ['21-Oct', '4호선', '106', '혜화', 720835, 730880, 111523, 109289]
# ['21-Oct', '4호선', '107', '동대문', 364399, 384967, 138320, 134760]
# ['21-Oct', '4호선', '108', '동대문역사문화공원(DDP)', 324817, 302179, 48745, 44705]
# ['21-Oct', '4호선', '109', '충무로', 520290, 543122, 102514, 103015]
# ['21-Oct', '4호선', '110', '명동', 406556, 429937, 51917, 53978]
# ['21-Oct', '4호선', '111', '회현(남대문시장)', 429124, 467908, 164641, 165842]
# ['21-Oct', '4호선', '112', '서울역', 216595, 360356, 32525, 40646]
# ['21-Oct', '4호선', '113', '숙대입구(갈월)', 280138, 273659, 45868, 42628]
# ['21-Oct', '4호선', '114', '삼각지', 107625, 126910, 20903, 22075]
# ['21-Oct', '4호선', '115', '신용산', 344692, 367292, 45845, 46311]
# ['21-Oct', '4호선', '116', '이촌(국립중앙박물관)', 151827, 171536, 39443, 41419]
# ['21-Oct', '4호선', '117', '동작(현충원)', 34180, 37700, 19600, 19128]
# ['21-Oct', '4호선', '118', '총신대입구(이수)', 368353, 402888, 142735, 150205]
# ['21-Oct', '4호선', '119', '사당', 568624, 477687, 78193, 78378]
# ['21-Oct', '4호선', '120', '남태령', 24680, 19629, 8232, 7775]
# ['21-Oct', '4호선', '95', '당고개', 259198, 233706, 81371, 80642]
# ['21-Oct', '4호선', '96', '상계', 391494, 359701, 106900, 104493]
# ['21-Oct', '4호선', '97', '노원', 422302, 474467, 78675, 77745]
# ['21-Oct', '4호선', '98', '창동', 496263, 525096, 164322, 169863]
# ['21-Oct', '4호선', '99', '쌍문', 620036, 559205, 142402, 140115]
# ['21-Oct', '경부선', '121', '서울역', 169652, 51551, 10900, 2523]
# ['21-Oct', '경부선', '122', '남영', 198598, 207846, 32026, 33448]
# ['21-Oct', '경부선', '123', '용산', 837655, 846995, 117015, 115268]
# ['21-Oct', '경부선', '124', '노량진', 204032, 204293, 37431, 34296]
# ['21-Oct', '경부선', '125', '대방', 259979, 268654, 60178, 60068]
# ['21-Oct', '경부선', '126', '영등포', 845883, 867282, 202077, 202100]
# ['21-Oct', '경부선', '127', '신도림', 84031, 83880, 24775, 27875]
# ['21-Oct', '경부선', '151', '신길', 195079, 161989, 44149, 41245]
# ['21-Oct', '경부선', '250', '구로', 396391, 407956, 87099, 83999]
# ['21-Oct', '경부선', '251', '가산디지털단지', 376667, 456195, 32749, 36852]
# ['21-Oct', '경부선', '252', '금천구청', 237786, 235459, 73682, 73949]
# ['21-Oct', '경부선', '253', '석수', 213415, 189388, 45835, 44320]
# ['21-Oct', '경부선', '254', '관악', 148808, 137078, 48878, 46609]
# ['21-Oct', '경부선', '255', '안양', 520385, 513991, 104061, 107789]
# ['21-Oct', '경부선', '256', '명학', 187019, 184525, 38525, 37689]
# ['21-Oct', '경부선', '257', '금정', 575994, 586978, 106920, 107819]
# ['21-Oct', '경부선', '258', '군포', 156967, 154370, 31825, 31150]
# ['21-Oct', '경부선', '259', '의왕', 193379, 192397, 41086, 40874]
# ['21-Oct', '경부선', '260', '성균관대', 321701, 320563, 47574, 47697]
# ['21-Oct', '경부선', '261', '화서', 163588, 158823, 39024, 38418]
# ['21-Oct', '경부선', '262', '수원', 895662, 943074, 132646, 134330]
# ['21-Oct', '경부선', '263', '독산', 372201, 386570, 59210, 60291]
# ['21-Oct', '경부선', '264', '세류', 69967, 64942, 14417, 14089]
# ['21-Oct', '경부선', '265', '병점', 335831, 339764, 58791, 58516]
# ['21-Oct', '경부선', '266', '세마', 60353, 56261, 14542, 13780]
# ['21-Oct', '경부선', '267', '오산대', 82759, 77093, 17348, 16699]
# ['21-Oct', '경부선', '268', '오산', 238919, 235974, 42965, 43671]
# ['21-Oct', '경부선', '269', '진위', 34656, 29918, 7534, 7249]
# ['21-Oct', '경부선', '270', '송탄', 109554, 104675, 19983, 19166]
# ['21-Oct', '경부선', '271', '서정리', 168078, 158801, 29429, 28702]
# ['21-Oct', '경부선', '272', '평택지제', 82101, 78734, 10909, 10548]
# ['21-Oct', '경부선', '273', '평택', 303781, 299508, 61597, 60098]
# ['21-Oct', '경부선', '274', '성환', 90321, 90384, 18741, 18759]
# ['21-Oct', '경부선', '275', '직산', 16998, 17304, 4656, 4513]
# ['21-Oct', '경부선', '276', '두정', 141230, 143096, 25792, 26190]
# ['21-Oct', '경부선', '277', '천안', 123516, 125048, 53061, 53883]
# ['21-Oct', '경부선', '278', '당정', 130175, 124570, 28452, 27455]
# ['21-Oct', '경부선', '279', '서동탄', 30787, 28233, 7757, 7357]
# ['21-Oct', '경부선', '280', '광명', 83532, 71624, 9063, 8589]
# ['21-Oct', '경인선', '294', '개봉', 428445, 423852, 140520, 145837]
# ['21-Oct', '경인선', '295', '오류동', 237971, 218396, 81678, 79703]
# ['21-Oct', '경인선', '296', '역곡', 569079, 560341, 141061, 143252]
# ['21-Oct', '경인선', '297', '부천', 706966, 709480, 184820, 187414]
# ['21-Oct', '경인선', '298', '송내', 576949, 578899, 109166, 108245]
# ['21-Oct', '경인선', '299', '부평', 698638, 753946, 125450, 127491]
# ['21-Oct', '경인선', '300', '백운', 137548, 133781, 53071, 53443]
# ['21-Oct', '경인선', '301', '동암', 317083, 321059, 86875, 88184]
# ['21-Oct', '경인선', '302', '주안', 426280, 386108, 80160, 71409]
# ['21-Oct', '경인선', '303', '제물포', 219989, 211056, 57831, 57619]
# ['21-Oct', '경인선', '304', '동인천', 273871, 261207, 108313, 104923]
# ['21-Oct', '경인선', '305', '인천', 78104, 56995, 41138, 37625]
# ['21-Oct', '경인선', '306', '구일', 127665, 128229, 38990, 38240]
# ['21-Oct', '경인선', '307', '소사', 184140, 179533, 57684, 57561]
# ['21-Oct', '경인선', '308', '부개', 170870, 157406, 57126, 56009]
# ['21-Oct', '경인선', '309', '간석', 114628, 108878, 40518, 39707]
# ['21-Oct', '경인선', '310', '도원', 56349, 56491, 26924, 28278]
# ['21-Oct', '경인선', '311', '온수(성공회대입구)', 138610, 131484, 44258, 42996]
# ['21-Oct', '경인선', '312', '중동', 182743, 169566, 63451, 62503]
# ['21-Oct', '경인선', '313', '도화', 75456, 68524, 36308, 34780]
# ['21-Oct', '경원선', '128', '이촌(국립중앙박물관)', 75894, 56210, 24331, 20954]
# ['21-Oct', '경원선', '129', '서빙고', 39158, 39075, 13701, 12933]
# ['21-Oct', '경원선', '130', '한남', 80745, 76173, 26170, 24518]
# ['21-Oct', '경원선', '131', '옥수', 1483, 1001, 92, 78]
# ['21-Oct', '경원선', '132', '응봉', 34141, 28694, 15714, 13985]
# ['21-Oct', '경원선', '133', '왕십리(성동구청)', 317379, 361813, 56037, 61927]
# ['21-Oct', '경원선', '134', '청량리(서울시립대입구)', 310112, 318866, 138651, 147692]
# ['21-Oct', '경원선', '136', '외대앞', 152501, 149721, 39564, 40467]
# ['21-Oct', '경원선', '137', '신이문', 159086, 144496, 62510, 60960]
# ['21-Oct', '경원선', '138', '석계', 163352, 184414, 58635, 62913]
# ['21-Oct', '경원선', '139', '광운대', 164409, 158841, 49298, 48044]
# ['21-Oct', '경원선', '140', '월계', 124935, 115711, 56473, 54117]
# ['21-Oct', '경원선', '141', '녹천', 86877, 71295, 36116, 32291]
# ['21-Oct', '경원선', '142', '창동', 5, 0, 0, 0]
# ['21-Oct', '경원선', '359', '방학', 163916, 158632, 96730, 94766]
# ['21-Oct', '경원선', '360', '도봉', 98527, 92645, 65553, 65173]
# ['21-Oct', '경원선', '361', '도봉산', 138688, 79013, 119546, 95864]
# ['21-Oct', '경원선', '362', '망월사', 139419, 141873, 63456, 65208]
# ['21-Oct', '경원선', '363', '회룡', 204118, 202339, 134070, 132547]
# ['21-Oct', '경원선', '364', '의정부', 412889, 426001, 96653, 98589]
# ['21-Oct', '경원선', '365', '가능', 128391, 120737, 53138, 52950]
# ['21-Oct', '경원선', '366', '녹양', 88933, 84669, 34759, 33520]
# ['21-Oct', '경원선', '367', '양주', 165881, 156439, 56882, 56077]
# ['21-Oct', '경원선', '368', '덕계', 62281, 55800, 21075, 20194]
# ['21-Oct', '경원선', '369', '덕정', 123943, 119287, 32855, 32878]
# ['21-Oct', '경원선', '370', '지행', 135839, 135169, 42315, 42301]
# ['21-Oct', '경원선', '371', '동두천중앙', 55027, 52697, 33208, 33270]
# ['21-Oct', '경원선', '372', '보산', 36432, 33560, 12739, 11996]
# ['21-Oct', '경원선', '373', '동두천', 35638, 40656, 22574, 28658]
# ['21-Oct', '경원선', '374', '소요산', 36476, 29865, 77461, 69584]
# ['21-Oct', '안산선', '281', '산본', 333670, 362506, 86951, 88231]
# ['21-Oct', '안산선', '282', '대야미', 105919, 94119, 30689, 29129]
# ['21-Oct', '안산선', '283', '반월', 89963, 85822, 27262, 26910]
# ['21-Oct', '안산선', '284', '상록수', 365583, 367317, 63771, 64852]
# ['21-Oct', '안산선', '285', '한대앞', 211203, 210331, 41972, 42574]
# ['21-Oct', '안산선', '286', '중앙', 432098, 448113, 53208, 52635]
# ['21-Oct', '안산선', '287', '고잔', 197891, 190547, 32930, 31786]
# ['21-Oct', '안산선', '288', '초지', 109535, 115733, 14977, 15153]
# ['21-Oct', '안산선', '289', '안산', 288202, 268127, 35523, 33455]
# ['21-Oct', '안산선', '290', '신길온천', 37599, 34852, 9816, 9751]
# ['21-Oct', '안산선', '291', '정왕', 216474, 223508, 24216, 25914]
# ['21-Oct', '안산선', '292', '오이도', 205128, 202141, 38433, 37865]
# ['21-Oct', '안산선', '293', '수리산', 80920, 65606, 29918, 28837]
# ['21-Oct', '과천선', '231', '선바위', 177040, 153229, 32060, 31511]
# ['21-Oct', '과천선', '232', '경마공원', 25738, 25339, 10207, 9679]
# ['21-Oct', '과천선', '233', '대공원', 80272, 84971, 56433, 57122]
# ['21-Oct', '과천선', '234', '과천', 113303, 102302, 36132, 34737]
# ['21-Oct', '과천선', '235', '정부과천청사', 211098, 208818, 46217, 45808]
# ['21-Oct', '과천선', '236', '인덕원', 506883, 523294, 96328, 99028]
# ['21-Oct', '과천선', '237', '평촌', 369903, 365311, 57839, 57427]
# ['21-Oct', '과천선', '238', '범계', 573394, 565438, 92991, 91229]
# ['21-Oct', '분당선', '143', '선릉', 260987, 396705, 37244, 48294]
# ['21-Oct', '분당선', '144', '한티', 314713, 331169, 57722, 58858]
# ['21-Oct', '분당선', '145', '도곡', 130077, 126251, 38814, 36566]
# ['21-Oct', '분당선', '146', '구룡', 40317, 38399, 12849, 12597]
# ['21-Oct', '분당선', '147', '개포동', 76621, 78837, 23017, 23410]
# ['21-Oct', '분당선', '148', '대모산입구', 83556, 75994, 27937, 28199]
# ['21-Oct', '분당선', '149', '수서', 302309, 310171, 59128, 60541]
# ['21-Oct', '분당선', '150', '복정', 12, 0, 0, 0]
# ['21-Oct', '분당선', '314', '수원', 192840, 162293, 28290, 26572]
# ['21-Oct', '분당선', '315', '서울숲', 262867, 268858, 29427, 27896]
# ['21-Oct', '분당선', '316', '압구정로데오', 461315, 515007, 40884, 39086]
# ['21-Oct', '분당선', '317', '강남구청', 199332, 234417, 34979, 37857]
# ['21-Oct', '분당선', '318', '선정릉', 158258, 171549, 24344, 24048]
# ['21-Oct', '분당선', '319', '가천대', 199517, 221233, 24166, 25272]
# ['21-Oct', '분당선', '320', '태평', 277269, 258474, 83855, 86587]
# ['21-Oct', '분당선', '321', '모란', 408415, 401926, 163096, 176346]
# ['21-Oct', '분당선', '322', '야탑', 519085, 547525, 128946, 128355]
# ['21-Oct', '분당선', '323', '서현', 520948, 532218, 103968, 99668]
# ['21-Oct', '분당선', '324', '수내', 259397, 258365, 66972, 65145]
# ['21-Oct', '분당선', '325', '정자', 361321, 383300, 57623, 59090]
# ['21-Oct', '분당선', '326', '미금', 296193, 314665, 95003, 101776]
# ['21-Oct', '분당선', '327', '오리', 231607, 191210, 65952, 56509]
# ['21-Oct', '분당선', '328', '이매', 114316, 107008, 35906, 34977]
# ['21-Oct', '분당선', '329', '보정', 45645, 39514, 17959, 16949]
# ['21-Oct', '분당선', '330', '죽전', 292624, 321589, 63082, 67907]
# ['21-Oct', '분당선', '331', '구성', 95645, 102795, 33221, 33011]
# ['21-Oct', '분당선', '332', '신갈', 86843, 86736, 26140, 26426]
# ['21-Oct', '분당선', '333', '기흥', 210967, 197401, 38600, 37530]
# ['21-Oct', '분당선', '334', '상갈', 113502, 111104, 29861, 28608]
# ['21-Oct', '분당선', '335', '청명', 91040, 86800, 17705, 17357]
# ['21-Oct', '분당선', '336', '영통', 191062, 193861, 25724, 25882]
# ['21-Oct', '분당선', '337', '망포', 324126, 305869, 33022, 31658]
# ['21-Oct', '분당선', '338', '매탄권선', 110375, 106715, 17911, 17213]
# ['21-Oct', '분당선', '339', '수원시청', 294975, 315414, 37171, 38008]
# ['21-Oct', '분당선', '340', '매교', 62100, 62830, 16630, 16851]
# ['21-Oct', '일산선', '375', '원흥', 216480, 206167, 53664, 51628]
# ['21-Oct', '일산선', '376', '지축', 3, 0, 0, 0]
# ['21-Oct', '일산선', '377', '삼송', 404768, 391774, 89799, 91091]
# ['21-Oct', '일산선', '378', '원당', 222777, 209769, 75742, 74814]
# ['21-Oct', '일산선', '379', '화정', 343473, 354034, 103461, 105477]
# ['21-Oct', '일산선', '380', '대곡', 38762, 29149, 12275, 11633]
# ['21-Oct', '일산선', '381', '백석', 196096, 196360, 63196, 62788]
# ['21-Oct', '일산선', '382', '마두', 135812, 139053, 59206, 60465]
# ['21-Oct', '일산선', '383', '정발산', 153303, 156797, 44461, 42121]
# ['21-Oct', '일산선', '384', '주엽', 159601, 156420, 75629, 78140]
# ['21-Oct', '일산선', '385', '대화', 264900, 212458, 72147, 67311]
# ['21-Oct', '중앙선', '135', '회기', 533231, 514715, 115181, 112529]
# ['21-Oct', '중앙선', '152', '중랑', 106321, 99912, 46189, 45159]
# ['21-Oct', '중앙선', '153', '상봉(시외버스터미널)', 129249, 127845, 39456, 37898]
# ['21-Oct', '중앙선', '154', '망우', 143855, 139880, 65191, 66234]
# ['21-Oct', '중앙선', '155', '양원', 35736, 36185, 16708, 16685]
# ['21-Oct', '중앙선', '156', '구리', 283796, 288364, 76814, 77032]
# ['21-Oct', '중앙선', '157', '도농', 205611, 188065, 56854, 55036]
# ['21-Oct', '중앙선', '158', '양정', 14340, 12274, 10134, 9489]
# ['21-Oct', '중앙선', '159', '덕소', 111189, 111735, 44696, 45084]
# ['21-Oct', '중앙선', '160', '도심', 46675, 35280, 17726, 16923]
# ['21-Oct', '중앙선', '161', '팔당', 24661, 26490, 10382, 10510]
# ['21-Oct', '중앙선', '162', '운길산', 20193, 18833, 14680, 14491]
# ['21-Oct', '중앙선', '163', '양수', 39748, 39382, 24324, 24741]
# ['21-Oct', '중앙선', '164', '신원', 4084, 3144, 4023, 3307]
# ['21-Oct', '중앙선', '165', '국수', 13575, 13153, 9276, 9451]
# ['21-Oct', '중앙선', '166', '아신', 12126, 12176, 6479, 6428]
# ['21-Oct', '중앙선', '167', '오빈', 5285, 5175, 4067, 4171]
# ['21-Oct', '중앙선', '168', '양평', 58036, 58201, 33005, 33658]
# ['21-Oct', '중앙선', '169', '원덕', 5820, 5490, 6478, 6340]
# ['21-Oct', '중앙선', '170', '용문', 34138, 33972, 45062, 44667]
# ['21-Oct', '중앙선', '171', '지평', 945, 1215, 1062, 1222]
# ['21-Oct', '장항선', '224', '봉명', 21881, 21103, 9223, 8769]
# ['21-Oct', '장항선', '225', '쌍용(나사렛대)', 49200, 45814, 11645, 11092]
# ['21-Oct', '장항선', '226', '아산', 86607, 76141, 11595, 10832]
# ['21-Oct', '장항선', '227', '탕정', 859, 819, 207, 209]
# ['21-Oct', '장항선', '228', '배방', 24810, 24480, 6543, 6380]
# ['21-Oct', '장항선', '229', '온양온천', 70312, 72178, 44681, 44934]
# ['21-Oct', '장항선', '230', '신창(순천향대)', 53180, 50237, 7470, 7088]
# ['21-Oct', '경의선', '173', '신촌', 16887, 20663, 3204, 3609]
# ['21-Oct', '경의선', '174', '효창공원앞', 59148, 68044, 13170, 14500]
# ['21-Oct', '경의선', '176', '서강대', 45469, 43617, 10803, 10115]
# ['21-Oct', '경의선', '178', '가좌', 100495, 94687, 40053, 39836]
# ['21-Oct', '경의선', '180', '수색', 52069, 53995, 13650, 13470]
# ['21-Oct', '경의선', '181', '화전', 35686, 32831, 9365, 9345]
# ['21-Oct', '경의선', '182', '강매', 63943, 55080, 17383, 16401]
# ['21-Oct', '경의선', '183', '행신', 172457, 172542, 31661, 32343]
# ['21-Oct', '경의선', '184', '능곡', 74351, 67900, 28125, 27508]
# ['21-Oct', '경의선', '185', '곡산', 11220, 11606, 5125, 5383]
# ['21-Oct', '경의선', '186', '백마', 146726, 139940, 32345, 32065]
# ['21-Oct', '경의선', '187', '풍산', 117983, 110090, 33573, 32850]
# ['21-Oct', '경의선', '188', '일산', 187870, 184321, 56149, 55698]
# ['21-Oct', '경의선', '189', '탄현', 166646, 158371, 35099, 34296]
# ['21-Oct', '경의선', '190', '야당', 161675, 157853, 31781, 30322]
# ['21-Oct', '경의선', '191', '운정', 145958, 137522, 35003, 34905]
# ['21-Oct', '경의선', '192', '금릉', 103972, 101265, 24181, 23927]
# ['21-Oct', '경의선', '193', '금촌', 135074, 134565, 42371, 43457]
# ['21-Oct', '경의선', '194', '월롱', 57471, 56304, 8245, 9358]
# ['21-Oct', '경의선', '195', '파주', 29566, 20787, 7468, 6422]
# ['21-Oct', '경의선', '196', '문산', 103473, 102778, 41236, 41423]
# ['21-Oct', '경의선', '197', '임진강', 553, 350, 584, 602]
# ['21-Oct', '경의선', '198', '서울역', 81588, 100926, 13459, 16455]
# ['21-Oct', '경의선', '199', '공덕', 78058, 68462, 12711, 12772]
# ['21-Oct', '경의선', '200', '홍대입구', 44097, 51049, 4502, 4951]
# ['21-Oct', '경의선', '201', '디지털미디어시티', 55314, 50678, 10794, 10745]
# ['21-Oct', '경의선', '202', '김포공항', 2, 0, 0, 0]
# ['21-Oct', '경의선', '203', '계양', 7, 0, 0, 0]
# ['21-Oct', '경의선', '204', '검암', 1, 0, 0, 0]
# ['21-Oct', '경춘선', '205', '신내', 35515, 34790, 15380, 14942]
# ['21-Oct', '경춘선', '206', '갈매', 62717, 52887, 18461, 17300]
# ['21-Oct', '경춘선', '207', '별내', 67554, 63844, 21304, 20452]
# ['21-Oct', '경춘선', '208', '퇴계원', 71949, 64795, 26487, 25663]
# ['21-Oct', '경춘선', '209', '사릉', 71787, 67490, 20135, 20555]
# ['21-Oct', '경춘선', '210', '금곡', 27081, 26074, 15238, 14854]
# ['21-Oct', '경춘선', '211', '평내호평', 126211, 122911, 42704, 40564]
# ['21-Oct', '경춘선', '212', '천마산', 29884, 27356, 17611, 18134]
# ['21-Oct', '경춘선', '213', '마석', 78853, 78073, 33114, 33419]
# ['21-Oct', '경춘선', '214', '대성리', 10645, 9431, 7140, 6631]
# ['21-Oct', '경춘선', '215', '청평', 33110, 32616, 17955, 17843]
# ['21-Oct', '경춘선', '216', '상천', 5114, 4221, 5394, 5207]
# ['21-Oct', '경춘선', '217', '가평', 46502, 46026, 21816, 21469]
# ['21-Oct', '경춘선', '218', '굴봉산', 2548, 2265, 2642, 2545]
# ['21-Oct', '경춘선', '219', '백양리', 1932, 1867, 1331, 1329]
# ['21-Oct', '경춘선', '220', '강촌', 13172, 12408, 6967, 7102]
# ['21-Oct', '경춘선', '221', '김유정', 8202, 9580, 5344, 5642]
# ['21-Oct', '경춘선', '222', '남춘천', 55467, 55891, 28214, 30307]
# ['21-Oct', '경춘선', '223', '춘천', 36505, 32756, 20360, 16455]
# ['21-Oct', '수인선', '341', '고색', 92678, 89688, 13935, 12796]
# ['21-Oct', '수인선', '342', '오목천', 70093, 63804, 11304, 11250]
# ['21-Oct', '수인선', '343', '어천', 17569, 17265, 4784, 5191]
# ['21-Oct', '수인선', '344', '야목', 6351, 5108, 2080, 1736]
# ['21-Oct', '수인선', '345', '사리', 102188, 88836, 16670, 15764]
# ['21-Oct', '수인선', '346', '달월', 1501, 1297, 1067, 691]
# ['21-Oct', '수인선', '347', '월곶', 55799, 52741, 14056, 13951]
# ['21-Oct', '수인선', '348', '소래포구', 116476, 114537, 97530, 95916]
# ['21-Oct', '수인선', '349', '인천논현', 118554, 125840, 28898, 29377]
# ['21-Oct', '수인선', '350', '호구포', 82024, 85023, 19055, 19080]
# ['21-Oct', '수인선', '351', '남동인더스파크', 46962, 51244, 6019, 6200]
# ['21-Oct', '수인선', '352', '원인재', 92509, 97252, 29098, 29244]
# ['21-Oct', '수인선', '353', '연수', 97883, 95848, 25599, 25231]
# ['21-Oct', '수인선', '354', '송도', 49079, 44961, 20391, 19989]
# ['21-Oct', '수인선', '355', '인하대', 132285, 123434, 24750, 24055]
# ['21-Oct', '수인선', '356', '숭의', 78622, 72285, 27658, 26367]
# ['21-Oct', '수인선', '357', '신포', 37811, 38232, 12840, 13054]
# ['21-Oct', '수인선', '358', '인천', 20282, 36531, 13859, 17897]
# ['21-Oct', '경강선', '239', '판교', 101934, 99505, 12536, 11064]
# ['21-Oct', '경강선', '240', '이매', 24695, 19379, 6163, 5737]
# ['21-Oct', '경강선', '241', '삼동', 48213, 43044, 10799, 10714]
# ['21-Oct', '경강선', '242', '경기광주', 161679, 154744, 27913, 28296]
# ['21-Oct', '경강선', '243', '초월', 67852, 63262, 12985, 12685]
# ['21-Oct', '경강선', '244', '곤지암', 50737, 51818, 13817, 14158]
# ['21-Oct', '경강선', '245', '신둔도예촌', 33681, 30938, 7153, 7149]
# ['21-Oct', '경강선', '246', '이천', 62535, 66010, 12502, 13531]
# ['21-Oct', '경강선', '247', '부발', 48723, 47959, 8270, 8037]
# ['21-Oct', '경강선', '248', '세종대왕릉', 6118, 6308, 3791, 4075]
# ['21-Oct', '경강선', '249', '여주', 56524, 57998, 16629, 16429]
# ['21-Oct', '5호선', '386', '방화', 128857, 123687, 46526, 44896]
# ['21-Oct', '5호선', '387', '개화산', 107919, 102784, 34462, 34524]
# ['21-Oct', '5호선', '388', '김포공항', 186778, 173059, 28907, 31170]
# ['21-Oct', '5호선', '389', '송정', 129328, 121314, 47210, 45991]
# ['21-Oct', '5호선', '390', '마곡', 211653, 211368, 35571, 34548]
# ['21-Oct', '5호선', '391', '발산', 420938, 441118, 81009, 78431]
# ['21-Oct', '5호선', '392', '우장산', 285642, 279795, 78312, 81600]
# ['21-Oct', '5호선', '393', '화곡', 592768, 551576, 129817, 124125]
# ['21-Oct', '5호선', '394', '까치산', 608775, 580851, 141403, 143037]
# ['21-Oct', '5호선', '395', '신정(은행정)', 289788, 232103, 54563, 53429]
# ['21-Oct', '5호선', '396', '목동', 345375, 375025, 74680, 75076]
# ['21-Oct', '5호선', '397', '오목교(목동운동장앞)', 478749, 517169, 74188, 74047]
# ['21-Oct', '5호선', '398', '양평', 149859, 147435, 24509, 24411]
# ['21-Oct', '5호선', '399', '영등포구청', 74782, 75551, 17557, 17641]
# ['21-Oct', '5호선', '400', '영등포시장', 192917, 200387, 52804, 53381]
# ['21-Oct', '5호선', '401', '신길', 90238, 97268, 10094, 10479]
# ['21-Oct', '5호선', '402', '여의도', 564803, 601770, 45034, 42094]
# ['21-Oct', '5호선', '403', '여의나루', 285789, 317193, 25630, 24678]
# ['21-Oct', '5호선', '404', '마포', 279944, 287797, 54248, 53392]
# ['21-Oct', '5호선', '405', '공덕', 288710, 308378, 38739, 36125]
# ['21-Oct', '5호선', '406', '애오개', 130801, 130111, 31814, 30823]
# ['21-Oct', '5호선', '407', '충정로(경기대입구)', 97113, 97179, 12492, 12876]
# ['21-Oct', '5호선', '408', '서대문', 373838, 378582, 56522, 52838]
# ['21-Oct', '5호선', '409', '광화문(세종문화회관)', 617079, 648958, 61522, 60496]
# ['21-Oct', '5호선', '410', '종로3가', 261870, 253043, 83350, 88314]
# ['21-Oct', '5호선', '411', '을지로4가', 104203, 109740, 39218, 38945]
# ['21-Oct', '5호선', '412', '동대문역사문화공원(DDP)', 55959, 66853, 7139, 7847]
# ['21-Oct', '5호선', '413', '청구', 77766, 75174, 23170, 18106]
# ['21-Oct', '5호선', '414', '신금호', 128898, 132527, 33543, 38003]
# ['21-Oct', '5호선', '415', '행당', 163486, 145020, 44319, 39589]
# ['21-Oct', '5호선', '416', '왕십리(성동구청)', 99185, 113939, 20005, 19885]
# ['21-Oct', '5호선', '417', '마장', 108767, 99792, 34089, 33109]
# ['21-Oct', '5호선', '418', '답십리', 325055, 295003, 70334, 67611]
# ['21-Oct', '5호선', '419', '장한평', 379729, 374961, 77027, 77766]
# ['21-Oct', '5호선', '420', '군자(능동)', 254153, 279794, 38293, 39601]
# ['21-Oct', '5호선', '421', '아차산(어린이대공원후문)', 311311, 302013, 91783, 89710]
# ['21-Oct', '5호선', '422', '광나루(장신대)', 283329, 261572, 65739, 63179]
# ['21-Oct', '5호선', '423', '천호(풍납토성)', 380783, 370588, 110097, 112924]
# ['21-Oct', '5호선', '424', '강동', 378292, 363104, 86759, 84357]
# ['21-Oct', '5호선', '425', '길동', 143495, 148904, 62897, 64774]
# ['21-Oct', '5호선', '426', '굽은다리(강동구민회관앞)', 186781, 178771, 60886, 56503]
# ['21-Oct', '5호선', '427', '명일', 162883, 165847, 59471, 61642]
# ['21-Oct', '5호선', '428', '고덕', 190357, 187412, 56135, 55955]
# ['21-Oct', '5호선', '429', '상일동', 309873, 281023, 77625, 74579]
# ['21-Oct', '5호선', '430', '둔촌동', 166176, 165557, 55994, 56323]
# ['21-Oct', '5호선', '431', '올림픽공원(한국체대)', 86104, 79684, 33769, 30859]
# ['21-Oct', '5호선', '432', '방이', 141217, 146126, 39960, 39663]
# ['21-Oct', '5호선', '433', '오금', 76311, 75818, 17910, 17758]
# ['21-Oct', '5호선', '434', '개롱', 125663, 131122, 41457, 42792]
# ['21-Oct', '5호선', '435', '거여', 175193, 165826, 53595, 52564]
# ['21-Oct', '5호선', '436', '마천', 124907, 121678, 49124, 50656]
# ['21-Oct', '5호선', '437', '강일', 69585, 67670, 25620, 25330]
# ['21-Oct', '5호선', '438', '미사', 348245, 345738, 62753, 62222]
# ['21-Oct', '5호선', '439', '하남풍산', 83529, 83547, 21948, 21686]
# ['21-Oct', '5호선', '440', '하남시청(덕풍·신장)', 111994, 107692, 49808, 50409]
# ['21-Oct', '5호선', '441', '하남검단산', 109877, 107277, 40102, 40083]
# ['21-Oct', '6호선', '442', '응암', 351789, 346735, 104153, 102870]
# ['21-Oct', '6호선', '443', '역촌', 69110, 87260, 29669, 29428]
# ['21-Oct', '6호선', '444', '불광', 81667, 85179, 34647, 29124]
# ['21-Oct', '6호선', '445', '독바위', 54029, 56476, 18920, 23058]
# ['21-Oct', '6호선', '446', '연신내', 47, 0, 1, 0]
# ['21-Oct', '6호선', '447', '구산', 154817, 104197, 46025, 47530]
# ['21-Oct', '6호선', '448', '새절(신사)', 250697, 230554, 79179, 79216]
# ['21-Oct', '6호선', '449', '증산(명지대앞)', 196131, 193354, 65426, 66240]
# ['21-Oct', '6호선', '450', '디지털미디어시티', 276821, 301111, 49122, 49202]
# ['21-Oct', '6호선', '451', '월드컵경기장(성산)', 94450, 106002, 68507, 68766]
# ['21-Oct', '6호선', '452', '마포구청', 290454, 258748, 70807, 62703]
# ['21-Oct', '6호선', '453', '망원', 307130, 332316, 75147, 78061]
# ['21-Oct', '6호선', '454', '합정', 320273, 310193, 36006, 33662]
# ['21-Oct', '6호선', '455', '상수', 198889, 224506, 18850, 18974]
# ['21-Oct', '6호선', '456', '광흥창(서강)', 179806, 172239, 39419, 38810]
# ['21-Oct', '6호선', '457', '대흥(서강대앞)', 163530, 168208, 38889, 38797]
# ['21-Oct', '6호선', '458', '공덕', 374316, 360781, 65203, 61003]
# ['21-Oct', '6호선', '459', '효창공원앞', 141629, 125358, 34459, 32362]
# ['21-Oct', '6호선', '460', '삼각지', 149336, 127138, 14587, 12084]
# ['21-Oct', '6호선', '461', '녹사평(용산구청)', 127251, 126007, 16281, 15678]
# ['21-Oct', '6호선', '462', '이태원', 292597, 303215, 28285, 29019]
# ['21-Oct', '6호선', '463', '한강진', 210390, 245623, 13760, 14004]
# ['21-Oct', '6호선', '464', '버티고개', 37531, 34010, 8833, 10308]
# ['21-Oct', '6호선', '465', '약수', 72830, 73789, 21449, 20887]
# ['21-Oct', '6호선', '466', '청구', 78923, 80683, 17462, 20375]
# ['21-Oct', '6호선', '467', '신당', 183497, 192690, 32437, 30822]
# ['21-Oct', '6호선', '468', '동묘앞', 161194, 166702, 63773, 58468]
# ['21-Oct', '6호선', '469', '창신', 71170, 57142, 16498, 15453]
# ['21-Oct', '6호선', '470', '보문', 158213, 145389, 26714, 25503]
# ['21-Oct', '6호선', '471', '안암(고대병원앞)', 226688, 227525, 28893, 27621]
# ['21-Oct', '6호선', '472', '고려대(종암)', 167420, 160302, 29843, 29754]
# ['21-Oct', '6호선', '473', '월곡(동덕여대)', 224599, 220329, 62529, 62205]
# ['21-Oct', '6호선', '474', '상월곡(한국과학기술연구원)', 124991, 109386, 36378, 35502]
# ['21-Oct', '6호선', '475', '돌곶이', 185880, 171551, 48791, 47854]
# ['21-Oct', '6호선', '476', '석계', 247039, 258369, 68817, 68757]
# ['21-Oct', '6호선', '477', '태릉입구', 115201, 127465, 27830, 29523]
# ['21-Oct', '6호선', '478', '화랑대(서울여대입구)', 248665, 193922, 42678, 37841]
# ['21-Oct', '6호선', '479', '봉화산(서울의료원)', 177056, 166836, 43985, 43406]
# ['21-Oct', '6호선', '480', '신내', 6, 0, 0, 0]
# ['21-Oct', '7호선', '481', '장암', 51531, 22716, 10388, 7711]
# ['21-Oct', '7호선', '482', '도봉산', 200902, 236814, 49999, 71825]
# ['21-Oct', '7호선', '483', '수락산', 257155, 253685, 89323, 90450]
# ['21-Oct', '7호선', '484', '마들', 253785, 236028, 75584, 75197]
# ['21-Oct', '7호선', '485', '노원', 401322, 425648, 103460, 104284]
# ['21-Oct', '7호선', '486', '중계', 284410, 256617, 80257, 77132]
# ['21-Oct', '7호선', '487', '하계', 363584, 339680, 90954, 88145]
# ['21-Oct', '7호선', '488', '공릉(서울과학기술대)', 247203, 244601, 62216, 62168]
# ['21-Oct', '7호선', '489', '태릉입구', 181739, 172361, 41413, 38815]
# ['21-Oct', '7호선', '490', '먹골', 208980, 201964, 57895, 58776]
# ['21-Oct', '7호선', '491', '중화', 224852, 219087, 58685, 58462]
# ['21-Oct', '7호선', '492', '상봉(시외버스터미널)', 376967, 356503, 65119, 62192]
# ['21-Oct', '7호선', '493', '면목', 321487, 312276, 86590, 88688]
# ['21-Oct', '7호선', '494', '사가정', 338376, 335905, 92411, 91328]
# ['21-Oct', '7호선', '495', '용마산(용마폭포공원)', 126669, 124313, 32768, 35154]
# ['21-Oct', '7호선', '496', '중곡', 210678, 193093, 54916, 55514]
# ['21-Oct', '7호선', '497', '군자(능동)', 311020, 246338, 67481, 58905]
# ['21-Oct', '7호선', '498', '어린이대공원(세종대)', 285068, 282137, 38621, 38226]
# ['21-Oct', '7호선', '499', '건대입구', 276290, 289101, 46695, 41805]
# ['21-Oct', '7호선', '500', '뚝섬유원지', 214882, 204390, 39618, 39974]
# ['21-Oct', '7호선', '501', '청담', 394758, 444929, 63276, 60309]
# ['21-Oct', '7호선', '502', '강남구청', 351956, 390685, 44223, 44929]
# ['21-Oct', '7호선', '503', '학동', 493628, 526705, 51371, 48197]
# ['21-Oct', '7호선', '504', '논현', 438221, 475746, 44496, 43806]
# ['21-Oct', '7호선', '505', '반포', 122101, 118200, 27838, 26192]
# ['21-Oct', '7호선', '506', '고속터미널', 369053, 297301, 64570, 55259]
# ['21-Oct', '7호선', '507', '내방', 289229, 294469, 57513, 56200]
# ['21-Oct', '7호선', '508', '이수', 337575, 327007, 70261, 66896]
# ['21-Oct', '7호선', '509', '남성', 219822, 200743, 59281, 58569]
# ['21-Oct', '7호선', '510', '숭실대입구(살피재)', 270031, 272677, 53396, 55003]
# ['21-Oct', '7호선', '511', '상도', 215443, 206671, 52865, 51294]
# ['21-Oct', '7호선', '512', '장승배기', 181818, 175773, 59686, 60274]
# ['21-Oct', '7호선', '513', '신대방삼거리', 333937, 315642, 79277, 81036]
# ['21-Oct', '7호선', '514', '보라매', 208980, 206723, 38702, 37709]
# ['21-Oct', '7호선', '515', '신풍', 239895, 225898, 62625, 63663]
# ['21-Oct', '7호선', '516', '대림(구로구청)', 191843, 193173, 32281, 31230]
# ['21-Oct', '7호선', '517', '남구로', 331453, 348658, 54521, 54400]
# ['21-Oct', '7호선', '518', '가산디지털단지', 948452, 937760, 80371, 75844]
# ['21-Oct', '7호선', '519', '철산', 449475, 459004, 87203, 86796]
# ['21-Oct', '7호선', '520', '광명사거리', 454832, 443597, 133053, 135951]
# ['21-Oct', '7호선', '521', '천왕', 236516, 223090, 48965, 48655]
# ['21-Oct', '7호선', '522', '온수(성공회대입구)', 227162, 210429, 35723, 34013]
# ['21-Oct', '7호선', '523', '까치울', 176093, 170950, 31047, 31241]
# ['21-Oct', '7호선', '524', '부천종합운동장', 103867, 90670, 19181, 18454]
# ['21-Oct', '7호선', '525', '춘의', 209880, 206293, 30609, 30122]
# ['21-Oct', '7호선', '526', '신중동', 312830, 315206, 48187, 46915]
# ['21-Oct', '7호선', '527', '부천시청', 285065, 283114, 51424, 49470]
# ['21-Oct', '7호선', '528', '상동', 300856, 314656, 46644, 46603]
# ['21-Oct', '7호선', '529', '삼산체육관', 113774, 103713, 24994, 23586]
# ['21-Oct', '7호선', '530', '굴포천', 202797, 213052, 33480, 34202]
# ['21-Oct', '7호선', '531', '부평구청', 167429, 149847, 24412, 22639]
# ['21-Oct', '8호선', '532', '암사', 378896, 332693, 95650, 94179]
# ['21-Oct', '8호선', '533', '천호(풍납토성)', 318960, 379946, 70994, 67819]
# ['21-Oct', '8호선', '534', '강동구청', 199008, 206923, 55623, 55823]
# ['21-Oct', '8호선', '535', '몽촌토성(평화의문)', 134624, 137470, 31827, 30431]
# ['21-Oct', '8호선', '536', '잠실(송파구청)', 311705, 376740, 58636, 56990]
# ['21-Oct', '8호선', '537', '석촌', 155655, 186937, 43180, 46419]
# ['21-Oct', '8호선', '538', '송파', 145948, 146678, 46888, 46695]
# ['21-Oct', '8호선', '539', '가락시장', 135107, 154056, 49889, 51232]
# ['21-Oct', '8호선', '540', '문정', 445728, 469255, 48337, 48064]
# ['21-Oct', '8호선', '541', '장지', 368489, 358352, 68760, 65180]
# ['21-Oct', '8호선', '542', '복정', 241437, 208181, 43196, 39444]
# ['21-Oct', '8호선', '543', '산성', 124315, 122490, 31156, 34781]
# ['21-Oct', '8호선', '544', '남한산성입구(성남법원.검찰청)', 282874, 255508, 72321, 69071]
# ['21-Oct', '8호선', '545', '단대오거리', 209324, 200125, 63023, 60167]
# ['21-Oct', '8호선', '546', '신흥', 82460, 89352, 32333, 33462]
# ['21-Oct', '8호선', '547', '수진', 100025, 88343, 36584, 35601]
# ['21-Oct', '8호선', '548', '모란', 78344, 62649, 49157, 39358]
# ['21-Oct', '9호선', '608', '개화', 55384, 39561, 12843, 10537]
# ['21-Oct', '9호선', '609', '김포공항', 207812, 333425, 17480, 22550]
# ['21-Oct', '9호선', '610', '공항시장', 56216, 60221, 22853, 24859]
# ['21-Oct', '9호선', '611', '신방화', 134824, 130229, 40891, 40490]
# ['21-Oct', '9호선', '612', '마곡나루(서울식물원)', 267596, 267464, 29064, 28359]
# ['21-Oct', '9호선', '613', '양천향교', 198283, 201246, 40263, 40372]
# ['21-Oct', '9호선', '614', '가양', 406117, 394619, 116175, 112555]
# ['21-Oct', '9호선', '615', '증미', 140696, 138876, 37474, 38238]
# ['21-Oct', '9호선', '616', '등촌', 214334, 209281, 72792, 73447]
# ['21-Oct', '9호선', '617', '염창', 371041, 358131, 63038, 61965]
# ['21-Oct', '9호선', '618', '신목동', 81218, 71846, 19096, 17843]
# ['21-Oct', '9호선', '619', '선유도', 175482, 169208, 26761, 25813]
# ['21-Oct', '9호선', '620', '당산', 395995, 398732, 56564, 52531]
# ['21-Oct', '9호선', '621', '국회의사당', 293739, 309790, 39999, 35184]
# ['21-Oct', '9호선', '622', '여의도', 563279, 538619, 38970, 36071]
# ['21-Oct', '9호선', '623', '샛강', 110170, 115288, 21697, 21841]
# ['21-Oct', '9호선', '624', '노량진', 611831, 595008, 76745, 78017]
# ['21-Oct', '9호선', '625', '노들', 89880, 74953, 28276, 25996]
# ['21-Oct', '9호선', '626', '흑석(중앙대입구)', 150197, 157165, 48134, 48221]
# ['21-Oct', '9호선', '627', '동작(현충원)', 38344, 30371, 11429, 10077]
# ['21-Oct', '9호선', '628', '구반포', 37870, 40169, 15751, 15574]
# ['21-Oct', '9호선', '629', '신반포', 68309, 67061, 17294, 17277]
# ['21-Oct', '9호선', '630', '고속터미널', 296684, 396218, 50983, 58493]
# ['21-Oct', '9호선', '631', '사평', 68415, 67127, 17712, 17844]
# ['21-Oct', '9호선', '632', '신논현', 741962, 731199, 52288, 48218]
# ['21-Oct', '공항철도 1호선', '646', '서울역', 192334, 183727, 29813, 26555]
# ['21-Oct', '공항철도 1호선', '647', '공덕', 50742, 67612, 6568, 7530]
# ['21-Oct', '공항철도 1호선', '648', '홍대입구', 263062, 260984, 16232, 15246]
# ['21-Oct', '공항철도 1호선', '649', '디지털미디어시티', 286913, 263467, 22451, 21101]
# ['21-Oct', '공항철도 1호선', '650', '마곡나루(서울식물원)', 175706, 172005, 12217, 12255]
# ['21-Oct', '공항철도 1호선', '651', '김포공항', 342297, 189221, 23677, 15211]
# ['21-Oct', '공항철도 1호선', '652', '계양', 228598, 214978, 27283, 25658]
# ['21-Oct', '공항철도 1호선', '653', '검암', 157999, 156346, 16870, 16902]
# ['21-Oct', '공항철도 1호선', '654', '청라국제도시', 153893, 146468, 11472, 11181]
# ['21-Oct', '공항철도 1호선', '655', '운서', 156953, 159041, 25854, 26039]
# ['21-Oct', '공항철도 1호선', '656', '공항화물청사', 48340, 53281, 8141, 8055]
# ['21-Oct', '공항철도 1호선', '657', '인천공항1터미널', 89581, 90275, 15432, 15262]
# ['21-Oct', '공항철도 1호선', '658', '인천공항2터미널', 52161, 48596, 6988, 6594]
# ['21-Oct', '공항철도 1호선', '659', '영종', 66724, 67972, 19561, 19601]
# ['21-Oct', '9호선2~3단계', '633', '언주', 224218, 230019, 24244, 24057]
# ['21-Oct', '9호선2~3단계', '634', '선정릉', 205666, 227262, 20999, 21582]
# ['21-Oct', '9호선2~3단계', '635', '삼성중앙', 134125, 141155, 19018, 19139]
# ['21-Oct', '9호선2~3단계', '636', '봉은사', 352072, 362850, 37898, 36181]
# ['21-Oct', '9호선2~3단계', '637', '종합운동장', 87986, 86735, 15872, 14198]
# ['21-Oct', '9호선2~3단계', '638', '삼전', 141938, 137435, 32021, 31199]
# ['21-Oct', '9호선2~3단계', '639', '석촌고분', 122814, 121093, 28642, 28783]
# ['21-Oct', '9호선2~3단계', '640', '석촌', 188918, 165930, 30547, 26556]
# ['21-Oct', '9호선2~3단계', '641', '송파나루', 106458, 114264, 22102, 22763]
# ['21-Oct', '9호선2~3단계', '642', '한성백제', 57606, 51281, 15237, 13643]
# ['21-Oct', '9호선2~3단계', '643', '올림픽공원(한국체대)', 156453, 162389, 27569, 27082]
# ['21-Oct', '9호선2~3단계', '644', '둔촌오륜', 24812, 22056, 5627, 5844]
# ['21-Oct', '9호선2~3단계', '645', '중앙보훈병원', 180064, 159215, 71410, 70180]
# ['21-Oct', '우이신설선', '703', '북한산우이', 59901, 53517, 35340, 36780]
# ['21-Oct', '우이신설선', '704', '솔밭공원', 39361, 35406, 25507, 26829]
# ['21-Oct', '우이신설선', '705', '4.19민주묘지', 47136, 45146, 33743, 29650]
# ['21-Oct', '우이신설선', '706', '가오리', 67784, 64150, 42263, 43493]
# ['21-Oct', '우이신설선', '707', '화계', 52907, 47353, 37661, 37855]
# ['21-Oct', '우이신설선', '708', '삼양', 29231, 29862, 24543, 26967]
# ['21-Oct', '우이신설선', '709', '삼양사거리', 34034, 34338, 33187, 32764]
# ['21-Oct', '우이신설선', '710', '솔샘', 110876, 100316, 34753, 35739]
# ['21-Oct', '우이신설선', '711', '북한산보국문', 119076, 110212, 39546, 39753]
# ['21-Oct', '우이신설선', '712', '정릉', 80616, 70311, 42140, 38705]
# ['21-Oct', '우이신설선', '713', '성신여대입구(돈암)', 61616, 71377, 26180, 24888]
# ['21-Oct', '우이신설선', '714', '보문', 26176, 25876, 13692, 13777]
# ['21-Oct', '우이신설선', '715', '신설동', 31729, 32903, 23652, 21185]

# %%
# 유임승차 / 무임승차 비율의 최댓값 찾기

import csv
f = open('subwayfee.csv', encoding='utf-8')
data = csv.reader(f)
next(data)
mx = 0
rate = 0
for row in data:
    for i in range(4, 8):
        row[i] = int(row[i])
    rate = row[4] / row[6]
    if rate > mx:
        mx = rate
print(mx)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-789afeaad337> in <module>
#      10     for i in range(4, 8):
#      11         row[i] = int(row[i])
# ---> 12     rate = row[4] / row[6]
#      13     if rate > mx:
#      14         mx = rate
#
# ZeroDivisionError: division by zero

# %%
# 오류 수정

import csv
f = open('subwayfee.csv', encoding='utf-8')
data = csv.reader(f)
next(data)
mx = 0
rate = 0
for row in data:
    for i in range(4, 8):
        row[i] = int(row[i])
    if row[6] != 0: # 만약 무임승차인원 값이 0이 아니라면
        rate = row[4] / row[6]
        if rate > mx: # 만약 rate 값이 mx 값보다 크다면
            mx = rate # mx 값을 rate 값으로 업데이트하기
            print(row, round(rate, 2)) # 업데이트된 값 출력하기
# Out:
# ['21-Oct', '1호선', '1', '서울역', 944239, 912544, 177275, 169112] 5.33
# ['21-Oct', '1호선', '2', '시청', 438336, 445371, 66943, 67070] 6.55
# ['21-Oct', '2호선', '11', '시청', 461536, 441619, 45265, 40536] 10.2
# ['21-Oct', '2호선', '19', '한양대', 171445, 183653, 11214, 11643] 15.29
# ['21-Oct', '2호선', '49', '홍대입구', 1393038, 1454651, 87877, 83882] 15.85
# ['21-Oct', '경원선', '131', '옥수', 1483, 1001, 92, 78] 16.12
# ['21-Oct', '6호선', '446', '연신내', 47, 0, 1, 0] 47.0
